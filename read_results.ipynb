# %% [markdown]
# Utility for reading csv result

# %%
import pandas as pd

# %%
filename = '20171207_1054.csv'

# %%
df = pd.read_csv(filename)
df
# Out:
#         date_time     station  temp  feels_like wind_speed wind_direction  \
# 0   20171207 1133  KMTCORVA10  23.9        24.0        0.0            NNE
# 1   20171207 1133    KMTLOLO7  23.8        24.0        2.3             NE
# 2   20171207 1133    KMTLOLO4  28.6        29.0        1.1            NNW
# 3   20171207 1133    KMTLOLO3  23.5        24.0        0.0            NNE
# 4   20171207 1133    KMTLOLO2  28.6        29.0         --             --
# 5   20171207 1133  KMTHAMIL13  22.7        23.0        0.0           West
# 6   20171207 1133   KMTHAMIL7  32.5        32.5         --             --
# 7   20171207 1133   KMTSTEVE8  23.9        24.0        1.1            NNE
# 8   20171207 1133   KMTCORVA9  25.5        26.0        2.7             NW
# 9   20171207 1133   KMTFLORE2  23.4        23.0        2.0            WNW
# 10  20171207 1133   KMTFLORE7  23.9        24.0        0.0             SE
# 11  20171207 1134  KMTSTEVE13  24.8        25.0        0.0          South
# ...
