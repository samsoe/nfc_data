# %% [markdown]
# #### api reference page :
# https://www.wunderground.com/weather/api/d/docs?d=data/history

# %% [markdown]
# local weather
# https://stackoverflow.com/questions/4770297/convert-utc-datetime-string-to-local-datetime-with-python

# %%
from datetime import timedelta, date, datetime
from urllib.request import urlopen
import pandas as pd
import credentials
import json
import os.path
import time

# %%
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %%
def call_api(url):
    f = urlopen(url)
    return f

# %%
def parse_url(api_result):
    json_string = api_result.read()
    parsed_json = json.loads(json_string)
    observations = parsed_json['history']['observations']
    return observations

# %%
def structure_dataframe(station_id, observations):
    df = pd.DataFrame(observations)
    
    # read date into datetime object and set as index
    df_date = df['date'].apply(pd.Series)
    
    # to_date time parses to utc
    df_datetime = pd.to_datetime(df_date['pretty'])
    df['utc_date'] = df_datetime
    df = df.set_index('utc_date')
    
    # drop redundancies and columns of no interest
    df = df.drop(['date', 'utcdate', 'UV', 'softwaretype', 'solarradiation'], axis=1)
    
    # add station id column
    df['station_id'] = station_id
    
    # reorder columns for legibility
    cols = df.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    df = df[cols]
       
    return df

# %%
def append_day(df_day, df_day2):
    df_append = df_day.append(df_day2)
    return df_append

# %%
def save_file(df_day, filepath):
    if os.path.isfile(filepath):
        with open(filepath, 'a') as f:
            df_day.to_csv(f, header=False)
    else:
        df_day.to_csv(filepath)

# %%
# retrieve list of identified stations from csv

filename = "../output/station_id-list.csv"
station_list = open(filename).read().split('\n')
station_list.remove('')

# NO HISTORY DATA
# [KMTCORVA23, KMTCORVA21, KMTFLORE1, KMTFLORE12, 
# KMTLOLO8, KMTMISSO62, KMTMISSO74, KMTSTEVE16]

# %%
# set date range

start_date = date(2017, 7, 1)
end_date = date(2017, 11, 1)

# %%
dates = []

for single_date in daterange(start_date, end_date):
        dates.append(single_date.strftime("history_%Y%m%d"))

# %%
# import api key
#api_key = credentials.api['key']
api_key = 'x'

# %%
# %%time

# Run full list
num_exec = 0

for station_id in station_list[41:]:
    for date in dates:
        # sleep to limit API call speed
        print(datetime.now().time())
        print(station_id)
        time.sleep(6)
        
        # url returns json of weather history of date and station
        url = "http://api.wunderground.com/api/" + api_key + "/" + date + "/q/pws:" + station_id + ".json"
        print(url)
        
        api_result = call_api(url)
        
        num_exec = num_exec + 1
        print(num_exec)
        
        try:
            observations = parse_url(api_result)
            df_day = structure_dataframe(station_id, observations) 
            save_file(df_day, "../output/180418-full_run.csv")
        except:
            pass
# Out:
# 14:41:45.788908
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170701/q/pws:KMTVICTO9.json
# 1
# 14:41:53.210124
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170702/q/pws:KMTVICTO9.json
# 2
# 14:42:00.567892
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170703/q/pws:KMTVICTO9.json
# 3
# 14:42:07.859509
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170704/q/pws:KMTVICTO9.json
# 4
# 14:42:14.868249
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170705/q/pws:KMTVICTO9.json
# 5
# 14:42:21.943834
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170706/q/pws:KMTVICTO9.json
# 6
# 14:42:29.018691
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170707/q/pws:KMTVICTO9.json
# 7
# 14:42:36.269890
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170708/q/pws:KMTVICTO9.json
# 8
# 14:42:43.485532
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170709/q/pws:KMTVICTO9.json
# 9
# 14:42:50.512957
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170710/q/pws:KMTVICTO9.json
# 10
# 14:42:57.502268
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170711/q/pws:KMTVICTO9.json
# 11
# 14:43:04.982582
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170712/q/pws:KMTVICTO9.json
# 12
# 14:43:12.270272
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170713/q/pws:KMTVICTO9.json
# 13
# 14:43:19.394816
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170714/q/pws:KMTVICTO9.json
# 14
# 14:43:27.241938
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170715/q/pws:KMTVICTO9.json
# 15
# 14:43:34.503681
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170716/q/pws:KMTVICTO9.json
# 16
# 14:43:41.893532
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170717/q/pws:KMTVICTO9.json
# 17
# 14:43:49.242141
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170718/q/pws:KMTVICTO9.json
# 18
# 14:43:56.291545
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170719/q/pws:KMTVICTO9.json
# 19
# 14:44:03.495588
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170720/q/pws:KMTVICTO9.json
# 20
# 14:44:10.562011
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170721/q/pws:KMTVICTO9.json
# 21
# 14:44:24.370977
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170722/q/pws:KMTVICTO9.json
# 22
# 14:44:31.647365
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170723/q/pws:KMTVICTO9.json
# 23
# 14:44:38.517388
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170724/q/pws:KMTVICTO9.json
# 24
# 14:44:45.780918
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170725/q/pws:KMTVICTO9.json
# 25
# 14:44:52.772165
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170726/q/pws:KMTVICTO9.json
# 26
# 14:44:59.797081
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170727/q/pws:KMTVICTO9.json
# 27
# 14:45:06.921807
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170728/q/pws:KMTVICTO9.json
# 28
# 14:45:14.189659
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170729/q/pws:KMTVICTO9.json
# 29
# 14:45:21.451431
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170730/q/pws:KMTVICTO9.json
# 30
# 14:45:28.530060
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170731/q/pws:KMTVICTO9.json
# 31
# 14:45:35.479183
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170801/q/pws:KMTVICTO9.json
# 32
# 14:45:42.928594
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170802/q/pws:KMTVICTO9.json
# 33
# 14:45:49.918201
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170803/q/pws:KMTVICTO9.json
# 34
# 14:45:57.037905
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170804/q/pws:KMTVICTO9.json
# 35
# 14:46:04.829294
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170805/q/pws:KMTVICTO9.json
# 36
# 14:46:12.044175
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170806/q/pws:KMTVICTO9.json
# 37
# 14:46:19.302151
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170807/q/pws:KMTVICTO9.json
# 38
# 14:46:26.343360
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170808/q/pws:KMTVICTO9.json
# 39
# 14:46:33.510394
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170809/q/pws:KMTVICTO9.json
# 40
# 14:46:40.616890
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170810/q/pws:KMTVICTO9.json
# 41
# 14:46:47.647132
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170811/q/pws:KMTVICTO9.json
# 42
# 14:46:54.815174
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170812/q/pws:KMTVICTO9.json
# 43
# 14:47:02.122295
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170813/q/pws:KMTVICTO9.json
# 44
# 14:47:09.199297
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170814/q/pws:KMTVICTO9.json
# 45
# 14:47:16.223983
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170815/q/pws:KMTVICTO9.json
# 46
# 14:47:23.289094
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170816/q/pws:KMTVICTO9.json
# 47
# 14:47:30.356883
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170817/q/pws:KMTVICTO9.json
# 48
# 14:47:37.325619
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170818/q/pws:KMTVICTO9.json
# 49
# 14:47:44.642481
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170819/q/pws:KMTVICTO9.json
# 50
# 14:47:51.611880
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170820/q/pws:KMTVICTO9.json
# 51
# 14:47:59.594808
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170821/q/pws:KMTVICTO9.json
# 52
# 14:48:06.657515
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170822/q/pws:KMTVICTO9.json
# 53
# 14:48:14.610743
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170823/q/pws:KMTVICTO9.json
# 54
# 14:48:21.689918
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170824/q/pws:KMTVICTO9.json
# 55
# 14:48:28.715382
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170825/q/pws:KMTVICTO9.json
# 56
# 14:48:35.826194
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170826/q/pws:KMTVICTO9.json
# 57
# 14:48:43.475348
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170827/q/pws:KMTVICTO9.json
# 58
# 14:48:50.620210
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170828/q/pws:KMTVICTO9.json
# 59
# 14:48:57.634978
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170829/q/pws:KMTVICTO9.json
# 60
# 14:49:04.696606
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170830/q/pws:KMTVICTO9.json
# 61
# 14:49:11.821298
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170831/q/pws:KMTVICTO9.json
# 62
# 14:49:18.748380
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170901/q/pws:KMTVICTO9.json
# 63
# 14:49:25.774071
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170902/q/pws:KMTVICTO9.json
# 64
# 14:49:33.027051
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170903/q/pws:KMTVICTO9.json
# 65
# 14:49:40.892294
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170904/q/pws:KMTVICTO9.json
# 66
# 14:49:48.011555
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170905/q/pws:KMTVICTO9.json
# 67
# 14:49:55.047367
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170906/q/pws:KMTVICTO9.json
# 68
# 14:50:02.059911
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170907/q/pws:KMTVICTO9.json
# 69
# 14:50:09.262541
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170908/q/pws:KMTVICTO9.json
# 70
# 14:50:16.551817
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170909/q/pws:KMTVICTO9.json
# 71
# 14:50:23.430841
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170910/q/pws:KMTVICTO9.json
# 72
# 14:50:30.963921
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170911/q/pws:KMTVICTO9.json
# 73
# 14:50:38.130955
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170912/q/pws:KMTVICTO9.json
# 74
# 14:50:45.500149
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170913/q/pws:KMTVICTO9.json
# 75
# 14:50:53.497237
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170914/q/pws:KMTVICTO9.json
# 76
# 14:51:00.574487
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170915/q/pws:KMTVICTO9.json
# 77
# 14:51:08.258485
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170916/q/pws:KMTVICTO9.json
# 78
# 14:51:15.249084
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170917/q/pws:KMTVICTO9.json
# 79
# 14:51:22.238544
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170918/q/pws:KMTVICTO9.json
# 80
# 14:51:29.397004
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170919/q/pws:KMTVICTO9.json
# 81
# 14:51:36.310656
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170920/q/pws:KMTVICTO9.json
# 82
# 14:51:43.516536
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170921/q/pws:KMTVICTO9.json
# 83
# 14:51:50.572262
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170922/q/pws:KMTVICTO9.json
# 84
# 14:51:57.540749
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170923/q/pws:KMTVICTO9.json
# 85
# 14:52:04.765813
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170924/q/pws:KMTVICTO9.json
# 86
# 14:52:11.709781
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170925/q/pws:KMTVICTO9.json
# 87
# 14:52:18.566614
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170926/q/pws:KMTVICTO9.json
# 88
# 14:52:25.629947
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170927/q/pws:KMTVICTO9.json
# 89
# 14:52:32.553377
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170928/q/pws:KMTVICTO9.json
# 90
# 14:52:39.813805
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170929/q/pws:KMTVICTO9.json
# 91
# 14:52:47.273705
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170930/q/pws:KMTVICTO9.json
# 92
# 14:52:54.549134
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171001/q/pws:KMTVICTO9.json
# 93
# 14:53:02.377907
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171002/q/pws:KMTVICTO9.json
# 94
# 14:53:10.822138
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171003/q/pws:KMTVICTO9.json
# 95
# 14:53:17.812233
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171004/q/pws:KMTVICTO9.json
# 96
# 14:53:24.681305
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171005/q/pws:KMTVICTO9.json
# 97
# 14:53:31.677777
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171006/q/pws:KMTVICTO9.json
# 98
# 14:53:38.733452
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171007/q/pws:KMTVICTO9.json
# 99
# 14:53:45.793212
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171008/q/pws:KMTVICTO9.json
# 100
# 14:53:52.754325
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171009/q/pws:KMTVICTO9.json
# 101
# 14:53:59.657289
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171010/q/pws:KMTVICTO9.json
# 102
# 14:54:06.686457
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171011/q/pws:KMTVICTO9.json
# 103
# 14:54:13.540480
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171012/q/pws:KMTVICTO9.json
# 104
# 14:54:20.427653
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171013/q/pws:KMTVICTO9.json
# 105
# 14:54:27.333804
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171014/q/pws:KMTVICTO9.json
# 106
# 14:54:35.136574
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171015/q/pws:KMTVICTO9.json
# 107
# 14:54:42.270669
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171016/q/pws:KMTVICTO9.json
# 108
# 14:54:49.457377
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171017/q/pws:KMTVICTO9.json
# 109
# 14:54:56.449080
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171018/q/pws:KMTVICTO9.json
# 110
# 14:55:03.584642
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171019/q/pws:KMTVICTO9.json
# 111
# 14:55:38.001647
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171020/q/pws:KMTVICTO9.json
# 112
# 14:55:45.283100
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171021/q/pws:KMTVICTO9.json
# 113
# 14:55:52.377200
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171022/q/pws:KMTVICTO9.json
# 114
# 14:55:59.579024
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171023/q/pws:KMTVICTO9.json
# 115
# 14:56:12.017637
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171024/q/pws:KMTVICTO9.json
# 116
# 14:56:19.261322
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171025/q/pws:KMTVICTO9.json
# 117
# 14:56:26.452114
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171026/q/pws:KMTVICTO9.json
# 118
# 14:56:34.060936
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171027/q/pws:KMTVICTO9.json
# 119
# 14:56:41.278778
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171028/q/pws:KMTVICTO9.json
# 120
# 14:56:48.355742
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171029/q/pws:KMTVICTO9.json
# 121
# 14:56:55.294628
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171030/q/pws:KMTVICTO9.json
# 122
# 14:57:02.391134
# KMTVICTO9
# http://api.wunderground.com/api/4be8042f62a3719a/history_20171031/q/pws:KMTVICTO9.json
# 123
# CPU times: user 19.9 s, sys: 1.21 s, total: 21.1 s
# Wall time: 15min 23s

# %%
df_day.tail()
# Out:
#                      station_id dewpti dewptm heatindexi heatindexm hum  \
# utc_date
# 2017-07-16 05:34:00  KMTHAMIL13   58.0   14.4      -9999      -9999  90
# 2017-07-16 05:40:00  KMTHAMIL13   58.0   14.4      -9999      -9999  90
# 2017-07-16 05:46:00  KMTHAMIL13   58.0   14.4      -9999      -9999  90
# 2017-07-16 05:51:00  KMTHAMIL13   58.0   14.4      -9999      -9999  90
# 2017-07-16 05:56:00  KMTHAMIL13   57.0   13.9      -9999      -9999  91
#
#                     precip_ratei precip_ratem precip_totali precip_totalm  \
# utc_date
# 2017-07-16 05:34:00         0.00          0.0          0.04           1.0
# 2017-07-16 05:40:00         0.00          0.0          0.04           1.0
# 2017-07-16 05:46:00         0.00          0.0          0.04           1.0
# 2017-07-16 05:51:00         0.00          0.0          0.04           1.0
# 2017-07-16 05:56:00         0.00          0.0          0.04           1.0
#
#                      ...  tempi tempm wdird  wdire  wgusti   wgustm  \
# utc_date             ...
# 2017-07-16 05:34:00  ...   61.7  16.5   203    SSW  -999.0  -1607.4
# 2017-07-16 05:40:00  ...   61.5  16.4   248    WSW  -999.0  -1607.4
# 2017-07-16 05:46:00  ...   61.5  16.4   135     SE  -999.0  -1607.4
# 2017-07-16 05:51:00  ...   61.1  16.2   270   West  -999.0  -1607.4
# 2017-07-16 05:56:00  ...   60.5  15.8   180  South  -999.0  -1607.4
#
#                     windchilli windchillm wspdi wspdm
# utc_date
# 2017-07-16 05:34:00       -999       -999   0.0   0.0
# 2017-07-16 05:40:00       -999       -999   0.0   0.0
# 2017-07-16 05:46:00       -999       -999   0.0   0.0
# 2017-07-16 05:51:00       -999       -999   0.0   0.0
# 2017-07-16 05:56:00       -999       -999   0.0   0.0
#
# [5 rows x 22 columns]

# %%
station_len = len(station_list)
dates_len = len(dates)

print(station_len, dates_len)
print(station_len*dates_len)
# Out:
# 42 123
# 5166

# %%
df_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2017-07-01 06:00:00 to 2017-07-02 05:56:00
# Data columns (total 22 columns):
# station_id       251 non-null object
# dewpti           251 non-null object
# dewptm           251 non-null object
# heatindexi       251 non-null object
# heatindexm       251 non-null object
# hum              251 non-null object
# precip_ratei     251 non-null object
# precip_ratem     251 non-null object
# precip_totali    251 non-null object
# precip_totalm    251 non-null object
# pressurei        251 non-null object
# pressurem        251 non-null object
# tempi            251 non-null object
# tempm            251 non-null object
# wdird            251 non-null object
# wdire            251 non-null object
# wgusti           251 non-null object
# wgustm           251 non-null object
# windchilli       251 non-null object
# windchillm       251 non-null object
# wspdi            251 non-null object
# wspdm            251 non-null object
# dtypes: object(22)
# memory usage: 45.1+ KB

# %%
df_day.head()
# Out:
#                      station_id dewpti dewptm heatindexi heatindexm hum  \
# utc_date
# 2017-07-01 06:00:00  KMTCORVA12   47.0    8.3      -9999      -9999  57
# 2017-07-01 06:06:00  KMTCORVA12   46.8    8.2      -9999      -9999  56
# 2017-07-01 06:11:00  KMTCORVA12   47.0    8.3      -9999      -9999  57
# 2017-07-01 06:16:00  KMTCORVA12   47.2    8.4      -9999      -9999  58
# 2017-07-01 06:21:00  KMTCORVA12   47.0    8.3      -9999      -9999  58
#
#                     precip_ratei precip_ratem precip_totali precip_totalm  \
# utc_date
# 2017-07-01 06:00:00         0.00          0.0          0.00           0.0
# 2017-07-01 06:06:00         0.00          0.0          0.00           0.0
# 2017-07-01 06:11:00         0.00          0.0          0.00           0.0
# 2017-07-01 06:16:00         0.00          0.0          0.00           0.0
# 2017-07-01 06:21:00         0.00          0.0          0.00           0.0
#
#                      ...  tempi tempm wdird  wdire  wgusti   wgustm  \
# utc_date             ...
# 2017-07-01 06:00:00  ...   62.3  16.8     0  North  -999.0  -1607.4
# 2017-07-01 06:06:00  ...   62.7  17.1   225     SW  -999.0  -1607.4
# 2017-07-01 06:11:00  ...   62.3  16.8    45     NE  -999.0  -1607.4
# 2017-07-01 06:16:00  ...   62.0  16.7    45     NE  -999.0  -1607.4
# 2017-07-01 06:21:00  ...   61.8  16.6    45     NE  -999.0  -1607.4
#
#                     windchilli windchillm wspdi wspdm
# utc_date
# 2017-07-01 06:00:00       -999       -999   1.5   2.4
# 2017-07-01 06:06:00       -999       -999   0.2   0.3
# 2017-07-01 06:11:00       -999       -999   1.2   1.9
# 2017-07-01 06:16:00       -999       -999   2.6   4.2
# 2017-07-01 06:21:00       -999       -999   1.7   2.7
#
# [5 rows x 22 columns]

# %%
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170828/q/pws:KMTSTEVE8.json

url = ""

for station_id in station_list[40:41]:
    for date in dates[58:]:
        url = "http://api.wunderground.com/api/" + api_key + "/" + date + "/q/pws:" + station_id + ".json"
        print(url)
# Out:
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170828/q/pws:KMTSTEVE8.json

# %%
# http://api.wunderground.com/api/4be8042f62a3719a/history_20170828/q/pws:KMTSTEVE8.json
for station_id in station_list[:]:
       print(station_id)
# Out:
# KMTCORVA9
# KMTCORVA10
# KMTCORVA23
# KMTCORVA12
# KMTCORVA15
# KMTCORVA21
# KMTFLORE12
# KMTFLORE4
# KMTFLORE5
# KMTFLORE7
# KMTFLORE2
# KMTFLORE1
# KMTFLORE17
# KMTFLORE18
# KMTFLORE13
# KMTFLORE11
# KMTFLORE3
# KMTHAMIL12
# MK6S5
# M6S59
# KMTHAMIL16
# KMTHAMIL1
# KMTHAMIL13
# KMTHAMIL7
# KMTHAMIL4
# KMTLEISU2
# KMTLOLO3
# KMTLOLO7
# KMTLOLO8
# KMTMISSO44
# KMTMISSO62
# KMTMISSO50
# KMTMISSO59
# KMTMISSO41
# KMTMISSO60
# KMTMISSO15
# KMTMISSO74
# KMTSTEVE12
# KMTSTEVE16
# KMTSTEVE13
# KMTSTEVE8
# KMTVICTO9

# %%
len(station_list)
# Out:
# 42

# %%
# last line of full_run.csv
# 2017-07-16 05:56:00,KMTHAMIL13

url = "http://api.wunderground.com/api/" + api_key + "/" + date + "/q/pws:" + station_id + ".json"
