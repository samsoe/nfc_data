# %% [markdown]
# ## Goal
# * Gather sunset and sunrise times from mso
#
# https://sunrise-sunset.org/api

# %%
# Import tools
from urllib.request import urlopen
from datetime import timedelta, date, datetime
from dateutil import tz
import json
import pandas as pd
import time
import os.path

# %% [markdown]
# ## Build Date Array

# %%
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

# Initialize date range
start_date = date(2017, 6, 30)
end_date = date(2017, 11,1)

dates = []

for single_date in daterange(start_date, end_date):
        dates.append(single_date.strftime("%Y-%m-%d"))

# %%
print(dates[:4])
print(dates[-4:])
# Out:
# ['2017-06-30', '2017-07-01', '2017-07-02', '2017-07-03']
# ['2017-10-28', '2017-10-29', '2017-10-30', '2017-10-31']

# %%
len(dates)
# Out:
# 124

# %% [markdown]
# ## Build URLs

# %%
def build_url_df(dates): 
    station = {'name' : 'MSO', 'lat' : '46.92083', 'lon': '-114.09250'}
    url_station = []

    for date in dates:
        row_url = 'https://api.sunrise-sunset.org/json?lat=' + str(station['lat']) \
        + '&lng=' + str(station['lon']) + '&date=' + date + '&formatted=0'
        url_station.append(row_url)

    return(url_station)

# %%
# Generate url list for api calls
url_batch = build_url_df(dates)

# %%
print(url_batch[0])
# Out:
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-06-30&formatted=0

# %% [markdown]
# ## Call API and store results

# %%
def api_call(url):
    f = urlopen(url)
    json_string = f.read()
    parsed_json = json.loads(json_string)
    
    return parsed_json['results']

# %%
def save_results(df_day, filepath):
    if os.path.isfile(filepath):
        with open(filepath, 'a') as f:
            df_day.to_csv(f, header=False, index=False)
    else:
        df_day.to_csv(filepath, index=False)

# %%
# %%time
successfull_calls = 0

# Loop over url_batch to call api and store results
for url in url_batch:
    # sleep to limit API call speed
    time.sleep(0)
    
    print(url)
    result = api_call(url)
        
    df_day = pd.DataFrame(result, index=[0])

    save_results(df_day, '../output/sunrise_sunset-mso-utc.csv')
    
    successfull_calls += 1
    print('successfull_calls: ' + str(successfull_calls))
# Out:
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-06-30&formatted=0
# successfull_calls: 1
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-01&formatted=0
# successfull_calls: 2
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-02&formatted=0
# successfull_calls: 3
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-03&formatted=0
# successfull_calls: 4
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-04&formatted=0
# successfull_calls: 5
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-05&formatted=0
# successfull_calls: 6
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-06&formatted=0
# successfull_calls: 7
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-07&formatted=0
# successfull_calls: 8
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-08&formatted=0
# successfull_calls: 9
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-09&formatted=0
# successfull_calls: 10
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-10&formatted=0
# successfull_calls: 11
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-11&formatted=0
# successfull_calls: 12
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-12&formatted=0
# successfull_calls: 13
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-13&formatted=0
# successfull_calls: 14
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-14&formatted=0
# successfull_calls: 15
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-15&formatted=0
# successfull_calls: 16
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-16&formatted=0
# successfull_calls: 17
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-17&formatted=0
# successfull_calls: 18
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-18&formatted=0
# successfull_calls: 19
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-19&formatted=0
# successfull_calls: 20
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-20&formatted=0
# successfull_calls: 21
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-21&formatted=0
# successfull_calls: 22
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-22&formatted=0
# successfull_calls: 23
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-23&formatted=0
# successfull_calls: 24
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-24&formatted=0
# successfull_calls: 25
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-25&formatted=0
# successfull_calls: 26
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-26&formatted=0
# successfull_calls: 27
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-27&formatted=0
# successfull_calls: 28
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07-28&formatted=0
# successfull_calls: 29
# https://api.sunrise-sunset.org/json?lat=46.92083&lng=-114.09250&date=2017-07